# %%
pip install google-generativeai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-generativeai in c:\users\sudar\appdata\roaming\python\python311\site-packages (0.5.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.2 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (0.6.2)
# Requirement already satisfied: google-api-core in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (2.19.0)
# Requirement already satisfied: google-api-python-client in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (2.129.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: protobuf in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (4.25.3)
# Requirement already satisfied: pydantic in c:\programdata\anaconda3\lib\site-packages (from google-generativeai) (1.10.8)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from google-generativeai) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-ai-generativelanguage==0.6.2->google-generativeai) (1.23.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.63.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\sudar\appdata\roaming\python\python311\site-packages (from google-api-core->google-generativeai) (1.62.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyB7MkBNlo7LnFl7RQkXrbCN4b4VBnWwlg4"
genai.configure(api_key=GOOGLE_API_KEY)

for m in genai.list_models():
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = genai.GenerativeModel("gemini-1.0-pro-vision-latest")
from PIL import Image

img = Image.open(r"C:\Users\sudar\Downloads\WhatsApp Image 2024-04-24 at 1.00.12 PM.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1600>

# %%
prompt="what is the meaning of picture?"
response = model.generate_content([prompt,img])
print(response.text)
# Out:
#  The picture shows a baby girl. She is wearing a cute headband with a flower on it and a striped dress. She has big brown eyes and a small nose. She is looking at the camera with a curious expression on her face. The picture is taken in a close-up view, which makes it easy to see the baby's features. The background is blurred, which helps to focus the attention on the baby. The picture is taken in a natural light, which gives it a warm and inviting feel.
